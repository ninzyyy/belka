# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Descriptors, rdMolDescriptors, Lipinski, GraphDescriptors, AllChem, MACCSkeys

# %%
def extract_molecule_info(smiles, name):

    mol = Chem.MolFromSmiles(smiles)
    if not mol:
        return pd.Series({})

    info = {
        f"{name}_mol_wt": Descriptors.MolWt(mol),
        f"{name}_logp": Descriptors.MolLogP(mol),
        f"{name}_atoms": mol.GetNumAtoms(),
        f"{name}_bonds": mol.GetNumBonds(),
        f"{name}_rotbonds": Lipinski.NumRotatableBonds(mol),
        f"{name}_hdonors": Lipinski.NumHDonors(mol),
        f"{name}_hacceptors": Lipinski.NumHAcceptors(mol),
        f"{name}_tpsa": rdMolDescriptors.CalcTPSA(mol),
        f"{name}_aromrings": rdMolDescriptors.CalcNumAromaticRings(mol),
        f"{name}_satrings": rdMolDescriptors.CalcNumSaturatedRings(mol),
        f"{name}_alirings": rdMolDescriptors.CalcNumAliphaticRings(mol),
        f"{name}_csp3": rdMolDescriptors.CalcFractionCSP3(mol),
        f"{name}_hka": rdMolDescriptors.CalcHallKierAlpha(mol),
        f"{name}_chi0n": GraphDescriptors.Chi0n(mol),
        f"{name}_chi1n": GraphDescriptors.Chi1n(mol),
        f"{name}_kappa1": GraphDescriptors.Kappa1(mol),
    }

    return pd.Series(info)

# %%
def generate_ecfp(smiles,
                  radius=2,
                  nBits=1024,
                  use_features=False,
                  use_chirality=False):

    molecule = Chem.MolFromSmiles(smiles)

    if molecule is None:
        return np.zeros((nBits,), dtype=np.uint8)

    feature_list = AllChem.GetMorganFingerprintAsBitVect(molecule,
                                                         radius=radius,
                                                         nBits=nBits,
                                                         useFeatures=use_features,
                                                         useChirality=use_chirality)
    # Add numpy to uint8

    return np.array(feature_list)

# %%
def smiles_to_maccs(smiles):

    molecule = Chem.MolFromSmiles(smiles)
    if molecule is None:
        return None
    else:
        maccs_key = MACCSkeys.GenMACCSKeys(molecule)
        return [int(bit) for bit in maccs_key.ToBitString()]

# %%
df = pd.read_parquet("data/test.parquet")
df
# Out:
#                 id                              buildingblock1_smiles  \
# 0        295246830    C#CCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O
# 1        295246831    C#CCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O
# 2        295246832    C#CCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O
# 3        295246833    C#CCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O
# 4        295246834    C#CCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc21)C(=O)O
# ...            ...                                                ...
# 1674891  296921721  [N-]=[N+]=NCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc...
# 1674892  296921722  [N-]=[N+]=NCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc...
# 1674893  296921723  [N-]=[N+]=NCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc...
# 1674894  296921724  [N-]=[N+]=NCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc...
# 1674895  296921725  [N-]=[N+]=NCCC[C@H](NC(=O)OCC1c2ccccc2-c2ccccc...
#
#         buildingblock2_smiles   buildingblock3_smiles  \
# 0              C=Cc1ccc(N)cc1          C=Cc1ccc(N)cc1
# 1              C=Cc1ccc(N)cc1          C=Cc1ccc(N)cc1
# 2              C=Cc1ccc(N)cc1          C=Cc1ccc(N)cc1
# 3              C=Cc1ccc(N)cc1  CC(O)Cn1cnc2c(N)ncnc21
# 4              C=Cc1ccc(N)cc1  CC(O)Cn1cnc2c(N)ncnc21
# ...                       ...                     ...
# 1674891     Nc1noc2ccc(F)cc12         COC1CCC(CCN)CC1
# 1674892     Nc1noc2ccc(F)cc12         COC1CCC(CCN)CC1
# 1674893     Nc1noc2ccc(F)cc12               NCc1cccs1
# 1674894     Nc1noc2ccc(F)cc12               NCc1cccs1
# 1674895     Nc1noc2ccc(F)cc12               NCc1cccs1
#
#                                            molecule_smiles protein_name
# 0        C#CCCC[C@H](Nc1nc(Nc2ccc(C=C)cc2)nc(Nc2ccc(C=C...         BRD4
# 1        C#CCCC[C@H](Nc1nc(Nc2ccc(C=C)cc2)nc(Nc2ccc(C=C...          HSA
# 2        C#CCCC[C@H](Nc1nc(Nc2ccc(C=C)cc2)nc(Nc2ccc(C=C...          sEH
# 3        C#CCCC[C@H](Nc1nc(Nc2ccc(C=C)cc2)nc(Nc2ncnc3c2...         BRD4
# 4        C#CCCC[C@H](Nc1nc(Nc2ccc(C=C)cc2)nc(Nc2ncnc3c2...          HSA
# ...                                                    ...          ...
# 1674891  COC1CCC(CCNc2nc(Nc3noc4ccc(F)cc34)nc(N[C@@H](C...          HSA
# 1674892  COC1CCC(CCNc2nc(Nc3noc4ccc(F)cc34)nc(N[C@@H](C...          sEH
# 1674893  [N-]=[N+]=NCCC[C@H](Nc1nc(NCc2cccs2)nc(Nc2noc3...         BRD4
# 1674894  [N-]=[N+]=NCCC[C@H](Nc1nc(NCc2cccs2)nc(Nc2noc3...          HSA
# 1674895  [N-]=[N+]=NCCC[C@H](Nc1nc(NCc2cccs2)nc(Nc2noc3...          sEH
#
# [1674896 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['id', 'buildingblock1_smiles', 'buildingblock2_smiles',
#        'buildingblock3_smiles', 'molecule_smiles', 'protein_name'],
#       dtype='object')

# %%
batch_size = 500
num_batches = (len(df) + batch_size - 1) // batch_size

all_fingerprints = []

for i in range(num_batches):
    batch = df.iloc[i*batch_size:(i+1)*batch_size]
    fingerprints = batch['molecule_smiles'].apply(generate_ecfp)
    all_fingerprints.append(np.vstack(fingerprints.values))
    print(f"Processed batch {i+1}/{num_batches}")

ecfp_matrix = np.vstack(all_fingerprints)
ecfp_matrix = ecfp_matrix.astype(np.uint8)
# Out:
# Processed batch 1/3350
# Processed batch 2/3350
# Processed batch 3/3350
# Processed batch 4/3350
# Processed batch 5/3350
# Processed batch 6/3350
# Processed batch 7/3350
# Processed batch 8/3350
# Processed batch 9/3350
# Processed batch 10/3350
# Processed batch 11/3350
# Processed batch 12/3350
# Processed batch 13/3350
# Processed batch 14/3350
# Processed batch 15/3350
# Processed batch 16/3350
# Processed batch 17/3350
# Processed batch 18/3350
# Processed batch 19/3350
# Processed batch 20/3350
# Processed batch 21/3350
# Processed batch 22/3350
# Processed batch 23/3350
# Processed batch 24/3350
# Processed batch 25/3350
# Processed batch 26/3350
# Processed batch 27/3350
# Processed batch 28/3350
# Processed batch 29/3350
# Processed batch 30/3350
# Processed batch 31/3350
# Processed batch 32/3350
# Processed batch 33/3350
# Processed batch 34/3350
# Processed batch 35/3350
# Processed batch 36/3350
# Processed batch 37/3350
# Processed batch 38/3350
# Processed batch 39/3350
# Processed batch 40/3350
# Processed batch 41/3350
# Processed batch 42/3350
# Processed batch 43/3350
# Processed batch 44/3350
# Processed batch 45/3350
# Processed batch 46/3350
# Processed batch 47/3350
# Processed batch 48/3350
# Processed batch 49/3350
# Processed batch 50/3350
# Processed batch 51/3350
# Processed batch 52/3350
# Processed batch 53/3350
# Processed batch 54/3350
# Processed batch 55/3350
# Processed batch 56/3350
# Processed batch 57/3350
# Processed batch 58/3350
# Processed batch 59/3350
# Processed batch 60/3350
# Processed batch 61/3350
# Processed batch 62/3350
# Processed batch 63/3350
# Processed batch 64/3350
# Processed batch 65/3350
# Processed batch 66/3350
# Processed batch 67/3350
# Processed batch 68/3350
# Processed batch 69/3350
# Processed batch 70/3350
# Processed batch 71/3350
# Processed batch 72/3350
# Processed batch 73/3350
# Processed batch 74/3350
# Processed batch 75/3350
# Processed batch 76/3350
# Processed batch 77/3350
# Processed batch 78/3350
# Processed batch 79/3350
# Processed batch 80/3350
# Processed batch 81/3350
# Processed batch 82/3350
# Processed batch 83/3350
# Processed batch 84/3350
# Processed batch 85/3350
# Processed batch 86/3350
# Processed batch 87/3350
# Processed batch 88/3350
# Processed batch 89/3350
# Processed batch 90/3350
# Processed batch 91/3350
# Processed batch 92/3350
# Processed batch 93/3350
# Processed batch 94/3350
# Processed batch 95/3350
# Processed batch 96/3350
# Processed batch 97/3350
# Processed batch 98/3350
# Processed batch 99/3350
# Processed batch 100/3350
# Processed batch 101/3350
# Processed batch 102/3350
# Processed batch 103/3350
# Processed batch 104/3350
# Processed batch 105/3350
# Processed batch 106/3350
# Processed batch 107/3350
# Processed batch 108/3350
# Processed batch 109/3350
# Processed batch 110/3350
# Processed batch 111/3350
# Processed batch 112/3350
# Processed batch 113/3350
# Processed batch 114/3350
# Processed batch 115/3350
# Processed batch 116/3350
# Processed batch 117/3350
# Processed batch 118/3350
# Processed batch 119/3350
# Processed batch 120/3350
# Processed batch 121/3350
# Processed batch 122/3350
# Processed batch 123/3350
# Processed batch 124/3350
# Processed batch 125/3350
# Processed batch 126/3350
# Processed batch 127/3350
# Processed batch 128/3350
# Processed batch 129/3350
# Processed batch 130/3350
# Processed batch 131/3350
# Processed batch 132/3350
# Processed batch 133/3350
# Processed batch 134/3350
# Processed batch 135/3350
# Processed batch 136/3350
# Processed batch 137/3350
# Processed batch 138/3350
# Processed batch 139/3350
# Processed batch 140/3350
# Processed batch 141/3350
# Processed batch 142/3350
# Processed batch 143/3350
# Processed batch 144/3350
# Processed batch 145/3350
# Processed batch 146/3350
# Processed batch 147/3350
# Processed batch 148/3350
# Processed batch 149/3350
# Processed batch 150/3350
# Processed batch 151/3350
# Processed batch 152/3350
# Processed batch 153/3350
# Processed batch 154/3350
# Processed batch 155/3350
# Processed batch 156/3350
# Processed batch 157/3350
# Processed batch 158/3350
# Processed batch 159/3350
# Processed batch 160/3350
# Processed batch 161/3350
# Processed batch 162/3350
# Processed batch 163/3350
# Processed batch 164/3350
# Processed batch 165/3350
# Processed batch 166/3350
# Processed batch 167/3350
# Processed batch 168/3350
# Processed batch 169/3350
# Processed batch 170/3350
# Processed batch 171/3350
# Processed batch 172/3350
# Processed batch 173/3350
# Processed batch 174/3350
# Processed batch 175/3350
# Processed batch 176/3350
# Processed batch 177/3350
# Processed batch 178/3350
# Processed batch 179/3350
# Processed batch 180/3350
# Processed batch 181/3350
# Processed batch 182/3350
# Processed batch 183/3350
# Processed batch 184/3350
# Processed batch 185/3350
# Processed batch 186/3350
# Processed batch 187/3350
# Processed batch 188/3350
# Processed batch 189/3350
# Processed batch 190/3350
# Processed batch 191/3350
# Processed batch 192/3350
# Processed batch 193/3350
# Processed batch 194/3350
# Processed batch 195/3350
# Processed batch 196/3350
# Processed batch 197/3350
# Processed batch 198/3350
# Processed batch 199/3350
# Processed batch 200/3350
# Processed batch 201/3350
# Processed batch 202/3350
# Processed batch 203/3350
# Processed batch 204/3350
# Processed batch 205/3350
# Processed batch 206/3350
# Processed batch 207/3350
# Processed batch 208/3350
# Processed batch 209/3350
# Processed batch 210/3350
# Processed batch 211/3350
# Processed batch 212/3350
# Processed batch 213/3350
# Processed batch 214/3350
# Processed batch 215/3350
# Processed batch 216/3350
# Processed batch 217/3350
# Processed batch 218/3350
# Processed batch 219/3350
# Processed batch 220/3350
# Processed batch 221/3350
# Processed batch 222/3350
# Processed batch 223/3350
# Processed batch 224/3350
# Processed batch 225/3350
# Processed batch 226/3350
# Processed batch 227/3350
# Processed batch 228/3350
# Processed batch 229/3350
# Processed batch 230/3350
# Processed batch 231/3350
# Processed batch 232/3350
# Processed batch 233/3350
# Processed batch 234/3350
# Processed batch 235/3350
# Processed batch 236/3350
# Processed batch 237/3350
# Processed batch 238/3350
# Processed batch 239/3350
# Processed batch 240/3350
# Processed batch 241/3350
# Processed batch 242/3350
# Processed batch 243/3350
# Processed batch 244/3350
# Processed batch 245/3350
# Processed batch 246/3350
# Processed batch 247/3350
# Processed batch 248/3350
# Processed batch 249/3350
# Processed batch 250/3350
# Processed batch 251/3350
# Processed batch 252/3350
# Processed batch 253/3350
# Processed batch 254/3350
# Processed batch 255/3350
# Processed batch 256/3350
# Processed batch 257/3350
# Processed batch 258/3350
# Processed batch 259/3350
# Processed batch 260/3350
# Processed batch 261/3350
# Processed batch 262/3350
# Processed batch 263/3350
# Processed batch 264/3350
# Processed batch 265/3350
# Processed batch 266/3350
# Processed batch 267/3350
# Processed batch 268/3350
# Processed batch 269/3350
# Processed batch 270/3350
# Processed batch 271/3350
# Processed batch 272/3350
# Processed batch 273/3350
# Processed batch 274/3350
# Processed batch 275/3350
# Processed batch 276/3350
# Processed batch 277/3350
# Processed batch 278/3350
# Processed batch 279/3350
# Processed batch 280/3350
# Processed batch 281/3350
# Processed batch 282/3350
# Processed batch 283/3350
# Processed batch 284/3350
# Processed batch 285/3350
# Processed batch 286/3350
# Processed batch 287/3350
# Processed batch 288/3350
# Processed batch 289/3350
# Processed batch 290/3350
# Processed batch 291/3350
# Processed batch 292/3350
# Processed batch 293/3350
# Processed batch 294/3350
# Processed batch 295/3350
# Processed batch 296/3350
# Processed batch 297/3350
# Processed batch 298/3350
# Processed batch 299/3350
# Processed batch 300/3350
# Processed batch 301/3350
# Processed batch 302/3350
# Processed batch 303/3350
# Processed batch 304/3350
# Processed batch 305/3350
# Processed batch 306/3350
# Processed batch 307/3350
# Processed batch 308/3350
# Processed batch 309/3350
# Processed batch 310/3350
# Processed batch 311/3350
# Processed batch 312/3350
# Processed batch 313/3350
# Processed batch 314/3350
# Processed batch 315/3350
# Processed batch 316/3350
# Processed batch 317/3350
# Processed batch 318/3350
# Processed batch 319/3350
# Processed batch 320/3350
# Processed batch 321/3350
# Processed batch 322/3350
# Processed batch 323/3350
# Processed batch 324/3350
# Processed batch 325/3350
# Processed batch 326/3350
# Processed batch 327/3350
# Processed batch 328/3350
# Processed batch 329/3350
# Processed batch 330/3350
# Processed batch 331/3350
# Processed batch 332/3350
# Processed batch 333/3350
# Processed batch 334/3350
# Processed batch 335/3350
# Processed batch 336/3350
# Processed batch 337/3350
# Processed batch 338/3350
# Processed batch 339/3350
# Processed batch 340/3350
# Processed batch 341/3350
# Processed batch 342/3350
# Processed batch 343/3350
# Processed batch 344/3350
# Processed batch 345/3350
# Processed batch 346/3350
# Processed batch 347/3350
# Processed batch 348/3350
# Processed batch 349/3350
# Processed batch 350/3350
# Processed batch 351/3350
# Processed batch 352/3350
# Processed batch 353/3350
# Processed batch 354/3350
# Processed batch 355/3350
# Processed batch 356/3350
# Processed batch 357/3350
# Processed batch 358/3350
# Processed batch 359/3350
# Processed batch 360/3350
# Processed batch 361/3350
# Processed batch 362/3350
# Processed batch 363/3350
# Processed batch 364/3350
# Processed batch 365/3350
# Processed batch 366/3350
# Processed batch 367/3350
# Processed batch 368/3350
# Processed batch 369/3350
# Processed batch 370/3350
# Processed batch 371/3350
# Processed batch 372/3350
# Processed batch 373/3350
# Processed batch 374/3350
# Processed batch 375/3350
# Processed batch 376/3350
# Processed batch 377/3350
# Processed batch 378/3350
# Processed batch 379/3350
# Processed batch 380/3350
# Processed batch 381/3350
# Processed batch 382/3350
# Processed batch 383/3350
# Processed batch 384/3350
# Processed batch 385/3350
# Processed batch 386/3350
# Processed batch 387/3350
# Processed batch 388/3350
# Processed batch 389/3350
# Processed batch 390/3350
# Processed batch 391/3350
# Processed batch 392/3350
# Processed batch 393/3350
# Processed batch 394/3350
# Processed batch 395/3350
# Processed batch 396/3350
# Processed batch 397/3350
# Processed batch 398/3350
# Processed batch 399/3350
# Processed batch 400/3350
# Processed batch 401/3350
# Processed batch 402/3350
# Processed batch 403/3350
# Processed batch 404/3350
# Processed batch 405/3350
# Processed batch 406/3350
# Processed batch 407/3350
# Processed batch 408/3350
# Processed batch 409/3350
# Processed batch 410/3350
# Processed batch 411/3350
# Processed batch 412/3350
# Processed batch 413/3350
# Processed batch 414/3350
# Processed batch 415/3350
# Processed batch 416/3350
# Processed batch 417/3350
# Processed batch 418/3350
# Processed batch 419/3350
# Processed batch 420/3350
# Processed batch 421/3350
# Processed batch 422/3350
# Processed batch 423/3350
# Processed batch 424/3350
# Processed batch 425/3350
# Processed batch 426/3350
# Processed batch 427/3350
# Processed batch 428/3350
# Processed batch 429/3350
# Processed batch 430/3350
# Processed batch 431/3350
# Processed batch 432/3350
# Processed batch 433/3350
# Processed batch 434/3350
# Processed batch 435/3350
# Processed batch 436/3350
# Processed batch 437/3350
# Processed batch 438/3350
# Processed batch 439/3350
# Processed batch 440/3350
# Processed batch 441/3350
# Processed batch 442/3350
# Processed batch 443/3350
# Processed batch 444/3350
# Processed batch 445/3350
# Processed batch 446/3350
# Processed batch 447/3350
# Processed batch 448/3350
# Processed batch 449/3350
# Processed batch 450/3350
# Processed batch 451/3350
# Processed batch 452/3350
# Processed batch 453/3350
# Processed batch 454/3350
# Processed batch 455/3350
# Processed batch 456/3350
# Processed batch 457/3350
# Processed batch 458/3350
# Processed batch 459/3350
# Processed batch 460/3350
# Processed batch 461/3350
# Processed batch 462/3350
# Processed batch 463/3350
# Processed batch 464/3350
# Processed batch 465/3350
# Processed batch 466/3350
# Processed batch 467/3350
# Processed batch 468/3350
# Processed batch 469/3350
# Processed batch 470/3350
# Processed batch 471/3350
# Processed batch 472/3350
# Processed batch 473/3350
# Processed batch 474/3350
# Processed batch 475/3350
# Processed batch 476/3350
# Processed batch 477/3350
# Processed batch 478/3350
# Processed batch 479/3350
# Processed batch 480/3350
# Processed batch 481/3350
# Processed batch 482/3350
# Processed batch 483/3350
# Processed batch 484/3350
# Processed batch 485/3350
# Processed batch 486/3350
# Processed batch 487/3350
# Processed batch 488/3350
# Processed batch 489/3350
# Processed batch 490/3350
# Processed batch 491/3350
# Processed batch 492/3350
# Processed batch 493/3350
# Processed batch 494/3350
# Processed batch 495/3350
# Processed batch 496/3350
# Processed batch 497/3350
# Processed batch 498/3350
# Processed batch 499/3350
# Processed batch 500/3350
# Processed batch 501/3350
# Processed batch 502/3350
# Processed batch 503/3350
# Processed batch 504/3350
# Processed batch 505/3350
# Processed batch 506/3350
# Processed batch 507/3350
# Processed batch 508/3350
# Processed batch 509/3350
# Processed batch 510/3350
# Processed batch 511/3350
# Processed batch 512/3350
# Processed batch 513/3350
# Processed batch 514/3350
# Processed batch 515/3350
# Processed batch 516/3350
# Processed batch 517/3350
# Processed batch 518/3350
# Processed batch 519/3350
# Processed batch 520/3350
# Processed batch 521/3350
# Processed batch 522/3350
# Processed batch 523/3350
# Processed batch 524/3350
# Processed batch 525/3350
# Processed batch 526/3350
# Processed batch 527/3350
# Processed batch 528/3350
# Processed batch 529/3350
# Processed batch 530/3350
# Processed batch 531/3350
# Processed batch 532/3350
# Processed batch 533/3350
# Processed batch 534/3350
# Processed batch 535/3350
# Processed batch 536/3350
# Processed batch 537/3350
# Processed batch 538/3350
# Processed batch 539/3350
# Processed batch 540/3350
# Processed batch 541/3350
# Processed batch 542/3350
# Processed batch 543/3350
# Processed batch 544/3350
# Processed batch 545/3350
# Processed batch 546/3350
# Processed batch 547/3350
# Processed batch 548/3350
# Processed batch 549/3350
# Processed batch 550/3350
# Processed batch 551/3350
# Processed batch 552/3350
# Processed batch 553/3350
# Processed batch 554/3350
# Processed batch 555/3350
# Processed batch 556/3350
# Processed batch 557/3350
# Processed batch 558/3350
# Processed batch 559/3350
# Processed batch 560/3350
# Processed batch 561/3350
# Processed batch 562/3350
# Processed batch 563/3350
# Processed batch 564/3350
# Processed batch 565/3350
# Processed batch 566/3350
# Processed batch 567/3350
# Processed batch 568/3350
# Processed batch 569/3350
# Processed batch 570/3350
# Processed batch 571/3350
# Processed batch 572/3350
# Processed batch 573/3350
# Processed batch 574/3350
# Processed batch 575/3350
# Processed batch 576/3350
# Processed batch 577/3350
# Processed batch 578/3350
# Processed batch 579/3350
# Processed batch 580/3350
# Processed batch 581/3350
# Processed batch 582/3350
# Processed batch 583/3350
# Processed batch 584/3350
# Processed batch 585/3350
# Processed batch 586/3350
# Processed batch 587/3350
# Processed batch 588/3350
# Processed batch 589/3350
# Processed batch 590/3350
# Processed batch 591/3350
# Processed batch 592/3350
# Processed batch 593/3350
# Processed batch 594/3350
# Processed batch 595/3350
# Processed batch 596/3350
# Processed batch 597/3350
# Processed batch 598/3350
# Processed batch 599/3350
# Processed batch 600/3350
# Processed batch 601/3350
# Processed batch 602/3350
# Processed batch 603/3350
# Processed batch 604/3350
# Processed batch 605/3350
# Processed batch 606/3350
# Processed batch 607/3350
# Processed batch 608/3350
# Processed batch 609/3350
# Processed batch 610/3350
# Processed batch 611/3350
# Processed batch 612/3350
# Processed batch 613/3350
# Processed batch 614/3350
# Processed batch 615/3350
# Processed batch 616/3350
# Processed batch 617/3350
# Processed batch 618/3350
# Processed batch 619/3350
# Processed batch 620/3350
# Processed batch 621/3350
# Processed batch 622/3350
# Processed batch 623/3350
# Processed batch 624/3350
# Processed batch 625/3350
# Processed batch 626/3350
# Processed batch 627/3350
# Processed batch 628/3350
# Processed batch 629/3350
# Processed batch 630/3350
# Processed batch 631/3350
# Processed batch 632/3350
# Processed batch 633/3350
# Processed batch 634/3350
# Processed batch 635/3350
# Processed batch 636/3350
# Processed batch 637/3350
# Processed batch 638/3350
# Processed batch 639/3350
# Processed batch 640/3350
# Processed batch 641/3350
# Processed batch 642/3350
# Processed batch 643/3350
# Processed batch 644/3350
# Processed batch 645/3350
# Processed batch 646/3350
# Processed batch 647/3350
# Processed batch 648/3350
# Processed batch 649/3350
# Processed batch 650/3350
# Processed batch 651/3350
# Processed batch 652/3350
# Processed batch 653/3350
# Processed batch 654/3350
# Processed batch 655/3350
# Processed batch 656/3350
# Processed batch 657/3350
# Processed batch 658/3350
# Processed batch 659/3350
# Processed batch 660/3350
# Processed batch 661/3350
# Processed batch 662/3350
# Processed batch 663/3350
# Processed batch 664/3350
# Processed batch 665/3350
# Processed batch 666/3350
# Processed batch 667/3350
# Processed batch 668/3350
# Processed batch 669/3350
# Processed batch 670/3350
# Processed batch 671/3350
# Processed batch 672/3350
# Processed batch 673/3350
# Processed batch 674/3350
# Processed batch 675/3350
# Processed batch 676/3350
# Processed batch 677/3350
# Processed batch 678/3350
# Processed batch 679/3350
# Processed batch 680/3350
# Processed batch 681/3350
# Processed batch 682/3350
# Processed batch 683/3350
# Processed batch 684/3350
# Processed batch 685/3350
# Processed batch 686/3350
# Processed batch 687/3350
# Processed batch 688/3350
# Processed batch 689/3350
# Processed batch 690/3350
# Processed batch 691/3350
# Processed batch 692/3350
# Processed batch 693/3350
# Processed batch 694/3350
# Processed batch 695/3350
# Processed batch 696/3350
# Processed batch 697/3350
# Processed batch 698/3350
# Processed batch 699/3350
# Processed batch 700/3350
# Processed batch 701/3350
# Processed batch 702/3350
# Processed batch 703/3350
# Processed batch 704/3350
# Processed batch 705/3350
# Processed batch 706/3350
# Processed batch 707/3350
# Processed batch 708/3350
# Processed batch 709/3350
# Processed batch 710/3350
# Processed batch 711/3350
# Processed batch 712/3350
# Processed batch 713/3350
# Processed batch 714/3350
# Processed batch 715/3350
# Processed batch 716/3350
# Processed batch 717/3350
# Processed batch 718/3350
# Processed batch 719/3350
# Processed batch 720/3350
# Processed batch 721/3350
# Processed batch 722/3350
# Processed batch 723/3350
# Processed batch 724/3350
# Processed batch 725/3350
# Processed batch 726/3350
# Processed batch 727/3350
# Processed batch 728/3350
# Processed batch 729/3350
# Processed batch 730/3350
# Processed batch 731/3350
# Processed batch 732/3350
# Processed batch 733/3350
# Processed batch 734/3350
# Processed batch 735/3350
# Processed batch 736/3350
# Processed batch 737/3350
# Processed batch 738/3350
# Processed batch 739/3350
# Processed batch 740/3350
# Processed batch 741/3350
# Processed batch 742/3350
# Processed batch 743/3350
# Processed batch 744/3350
# Processed batch 745/3350
# Processed batch 746/3350
# Processed batch 747/3350
# Processed batch 748/3350
# Processed batch 749/3350
# Processed batch 750/3350
# Processed batch 751/3350
# Processed batch 752/3350
# Processed batch 753/3350
# Processed batch 754/3350
# Processed batch 755/3350
# Processed batch 756/3350
# Processed batch 757/3350
# Processed batch 758/3350
# Processed batch 759/3350
# Processed batch 760/3350
# Processed batch 761/3350
# Processed batch 762/3350
# Processed batch 763/3350
# Processed batch 764/3350
# Processed batch 765/3350
# Processed batch 766/3350
# Processed batch 767/3350
# Processed batch 768/3350
# Processed batch 769/3350
# Processed batch 770/3350
# Processed batch 771/3350
# Processed batch 772/3350
# Processed batch 773/3350
# Processed batch 774/3350
# Processed batch 775/3350
# Processed batch 776/3350
# Processed batch 777/3350
# Processed batch 778/3350
# Processed batch 779/3350
# Processed batch 780/3350
# Processed batch 781/3350
# Processed batch 782/3350
# Processed batch 783/3350
# Processed batch 784/3350
# Processed batch 785/3350
# Processed batch 786/3350
# Processed batch 787/3350
# Processed batch 788/3350
# Processed batch 789/3350
# Processed batch 790/3350
# Processed batch 791/3350
# Processed batch 792/3350
# Processed batch 793/3350
# Processed batch 794/3350
# Processed batch 795/3350
# Processed batch 796/3350
# Processed batch 797/3350
# Processed batch 798/3350
# Processed batch 799/3350
# Processed batch 800/3350
# Processed batch 801/3350
# Processed batch 802/3350
# Processed batch 803/3350
# Processed batch 804/3350
# Processed batch 805/3350
# Processed batch 806/3350
# Processed batch 807/3350
# Processed batch 808/3350
# Processed batch 809/3350
# Processed batch 810/3350
# Processed batch 811/3350
# Processed batch 812/3350
# Processed batch 813/3350
# Processed batch 814/3350
# Processed batch 815/3350
# Processed batch 816/3350
# Processed batch 817/3350
# Processed batch 818/3350
# Processed batch 819/3350
# Processed batch 820/3350
# Processed batch 821/3350
# Processed batch 822/3350
# Processed batch 823/3350
# Processed batch 824/3350
# Processed batch 825/3350
# Processed batch 826/3350
# Processed batch 827/3350
# Processed batch 828/3350
# Processed batch 829/3350
# Processed batch 830/3350
# Processed batch 831/3350
# Processed batch 832/3350
# Processed batch 833/3350
# Processed batch 834/3350
# Processed batch 835/3350
# Processed batch 836/3350
# Processed batch 837/3350
# Processed batch 838/3350
# Processed batch 839/3350
# Processed batch 840/3350
# Processed batch 841/3350
# Processed batch 842/3350
# Processed batch 843/3350
# Processed batch 844/3350
# Processed batch 845/3350
# Processed batch 846/3350
# Processed batch 847/3350
# Processed batch 848/3350
# Processed batch 849/3350
# Processed batch 850/3350
# Processed batch 851/3350
# Processed batch 852/3350
# Processed batch 853/3350
# Processed batch 854/3350
# Processed batch 855/3350
# Processed batch 856/3350
# Processed batch 857/3350
# Processed batch 858/3350
# Processed batch 859/3350
# Processed batch 860/3350
# Processed batch 861/3350
# Processed batch 862/3350
# Processed batch 863/3350
# Processed batch 864/3350
# Processed batch 865/3350
# Processed batch 866/3350
# Processed batch 867/3350
# Processed batch 868/3350
# Processed batch 869/3350
# Processed batch 870/3350
# Processed batch 871/3350
# Processed batch 872/3350
# Processed batch 873/3350
# Processed batch 874/3350
# Processed batch 875/3350
# Processed batch 876/3350
# Processed batch 877/3350
# Processed batch 878/3350
# Processed batch 879/3350
# Processed batch 880/3350
# Processed batch 881/3350
# Processed batch 882/3350
# Processed batch 883/3350
# Processed batch 884/3350
# Processed batch 885/3350
# Processed batch 886/3350
# Processed batch 887/3350
# Processed batch 888/3350
# Processed batch 889/3350
# Processed batch 890/3350
# Processed batch 891/3350
# Processed batch 892/3350
# Processed batch 893/3350
# Processed batch 894/3350
# Processed batch 895/3350
# Processed batch 896/3350
# Processed batch 897/3350
# Processed batch 898/3350
# Processed batch 899/3350
# Processed batch 900/3350
# Processed batch 901/3350
# Processed batch 902/3350
# Processed batch 903/3350
# Processed batch 904/3350
# Processed batch 905/3350
# Processed batch 906/3350
# Processed batch 907/3350
# Processed batch 908/3350
# Processed batch 909/3350
# Processed batch 910/3350
# Processed batch 911/3350
# Processed batch 912/3350
# Processed batch 913/3350
# Processed batch 914/3350
# Processed batch 915/3350
# Processed batch 916/3350
# Processed batch 917/3350
# Processed batch 918/3350
# Processed batch 919/3350
# Processed batch 920/3350
# Processed batch 921/3350
# Processed batch 922/3350
# Processed batch 923/3350
# Processed batch 924/3350
# Processed batch 925/3350
# Processed batch 926/3350
# Processed batch 927/3350
# Processed batch 928/3350
# Processed batch 929/3350
# Processed batch 930/3350
# Processed batch 931/3350
# Processed batch 932/3350
# Processed batch 933/3350
# Processed batch 934/3350
# Processed batch 935/3350
# Processed batch 936/3350
# Processed batch 937/3350
# Processed batch 938/3350
# Processed batch 939/3350
# Processed batch 940/3350
# Processed batch 941/3350
# Processed batch 942/3350
# Processed batch 943/3350
# Processed batch 944/3350
# Processed batch 945/3350
# Processed batch 946/3350
# Processed batch 947/3350
# Processed batch 948/3350
# Processed batch 949/3350
# Processed batch 950/3350
# Processed batch 951/3350
# Processed batch 952/3350
# Processed batch 953/3350
# Processed batch 954/3350
# Processed batch 955/3350
# Processed batch 956/3350
# Processed batch 957/3350
# Processed batch 958/3350
# Processed batch 959/3350
# Processed batch 960/3350
# Processed batch 961/3350
# Processed batch 962/3350
# Processed batch 963/3350
# Processed batch 964/3350
# Processed batch 965/3350
# Processed batch 966/3350
# Processed batch 967/3350
# Processed batch 968/3350
# Processed batch 969/3350
# Processed batch 970/3350
# Processed batch 971/3350
# Processed batch 972/3350
# Processed batch 973/3350
# Processed batch 974/3350
# Processed batch 975/3350
# Processed batch 976/3350
# Processed batch 977/3350
# Processed batch 978/3350
# Processed batch 979/3350
# Processed batch 980/3350
# Processed batch 981/3350
# Processed batch 982/3350
# Processed batch 983/3350
# Processed batch 984/3350
# Processed batch 985/3350
# Processed batch 986/3350
# Processed batch 987/3350
# Processed batch 988/3350
# Processed batch 989/3350
# Processed batch 990/3350
# Processed batch 991/3350
# Processed batch 992/3350
# Processed batch 993/3350
# Processed batch 994/3350
# Processed batch 995/3350
# Processed batch 996/3350
# Processed batch 997/3350
# Processed batch 998/3350
# Processed batch 999/3350
# Processed batch 1000/3350
# Processed batch 1001/3350
# Processed batch 1002/3350
# Processed batch 1003/3350
# Processed batch 1004/3350
# Processed batch 1005/3350
# Processed batch 1006/3350
# Processed batch 1007/3350
# Processed batch 1008/3350
# Processed batch 1009/3350
# Processed batch 1010/3350
# Processed batch 1011/3350
# Processed batch 1012/3350
# Processed batch 1013/3350
# Processed batch 1014/3350
# Processed batch 1015/3350
# Processed batch 1016/3350
# Processed batch 1017/3350
# Processed batch 1018/3350
# Processed batch 1019/3350
# Processed batch 1020/3350
# Processed batch 1021/3350
# Processed batch 1022/3350
# Processed batch 1023/3350
# Processed batch 1024/3350
# Processed batch 1025/3350
# Processed batch 1026/3350
# Processed batch 1027/3350
# Processed batch 1028/3350
# Processed batch 1029/3350
# Processed batch 1030/3350
# Processed batch 1031/3350
# Processed batch 1032/3350
# Processed batch 1033/3350
# Processed batch 1034/3350
# Processed batch 1035/3350
# Processed batch 1036/3350
# Processed batch 1037/3350
# Processed batch 1038/3350
# Processed batch 1039/3350
# Processed batch 1040/3350
# Processed batch 1041/3350
# Processed batch 1042/3350
# Processed batch 1043/3350
# Processed batch 1044/3350
# Processed batch 1045/3350
# Processed batch 1046/3350
# Processed batch 1047/3350
# Processed batch 1048/3350
# Processed batch 1049/3350
# Processed batch 1050/3350
# Processed batch 1051/3350
# Processed batch 1052/3350
# Processed batch 1053/3350
# Processed batch 1054/3350
# Processed batch 1055/3350
# Processed batch 1056/3350
# Processed batch 1057/3350
# Processed batch 1058/3350
# Processed batch 1059/3350
# Processed batch 1060/3350
# Processed batch 1061/3350
# Processed batch 1062/3350
# Processed batch 1063/3350
# Processed batch 1064/3350
# Processed batch 1065/3350
# Processed batch 1066/3350
# Processed batch 1067/3350
# Processed batch 1068/3350
# Processed batch 1069/3350
# Processed batch 1070/3350
# Processed batch 1071/3350
# Processed batch 1072/3350
# Processed batch 1073/3350
# Processed batch 1074/3350
# Processed batch 1075/3350
# Processed batch 1076/3350
# Processed batch 1077/3350
# Processed batch 1078/3350
# Processed batch 1079/3350
# Processed batch 1080/3350
# Processed batch 1081/3350
# Processed batch 1082/3350
# Processed batch 1083/3350
# Processed batch 1084/3350
# Processed batch 1085/3350
# Processed batch 1086/3350
# Processed batch 1087/3350
# Processed batch 1088/3350
# Processed batch 1089/3350
# Processed batch 1090/3350
# Processed batch 1091/3350
# Processed batch 1092/3350
# Processed batch 1093/3350
# Processed batch 1094/3350
# Processed batch 1095/3350
# Processed batch 1096/3350
# Processed batch 1097/3350
# Processed batch 1098/3350
# Processed batch 1099/3350
# Processed batch 1100/3350
# Processed batch 1101/3350
# Processed batch 1102/3350
# Processed batch 1103/3350
# Processed batch 1104/3350
# Processed batch 1105/3350
# Processed batch 1106/3350
# Processed batch 1107/3350
# Processed batch 1108/3350
# Processed batch 1109/3350
# Processed batch 1110/3350
# Processed batch 1111/3350
# Processed batch 1112/3350
# Processed batch 1113/3350
# Processed batch 1114/3350
# Processed batch 1115/3350
# Processed batch 1116/3350
# Processed batch 1117/3350
# Processed batch 1118/3350
# Processed batch 1119/3350
# Processed batch 1120/3350
# Processed batch 1121/3350
# Processed batch 1122/3350
# Processed batch 1123/3350
# Processed batch 1124/3350
# Processed batch 1125/3350
# Processed batch 1126/3350
# Processed batch 1127/3350
# Processed batch 1128/3350
# Processed batch 1129/3350
# Processed batch 1130/3350
# Processed batch 1131/3350
# Processed batch 1132/3350
# Processed batch 1133/3350
# Processed batch 1134/3350
# Processed batch 1135/3350
# Processed batch 1136/3350
# Processed batch 1137/3350
# Processed batch 1138/3350
# Processed batch 1139/3350
# Processed batch 1140/3350
# Processed batch 1141/3350
# Processed batch 1142/3350
# Processed batch 1143/3350
# Processed batch 1144/3350
# Processed batch 1145/3350
# Processed batch 1146/3350
# Processed batch 1147/3350
# Processed batch 1148/3350
# Processed batch 1149/3350
# Processed batch 1150/3350
# Processed batch 1151/3350
# Processed batch 1152/3350
# Processed batch 1153/3350
# Processed batch 1154/3350
# Processed batch 1155/3350
# Processed batch 1156/3350
# Processed batch 1157/3350
# Processed batch 1158/3350
# Processed batch 1159/3350
# Processed batch 1160/3350
# Processed batch 1161/3350
# Processed batch 1162/3350
# Processed batch 1163/3350
# Processed batch 1164/3350
# Processed batch 1165/3350
# Processed batch 1166/3350
# Processed batch 1167/3350
# Processed batch 1168/3350
# Processed batch 1169/3350
# Processed batch 1170/3350
# Processed batch 1171/3350
# Processed batch 1172/3350
# Processed batch 1173/3350
# Processed batch 1174/3350
# Processed batch 1175/3350
# Processed batch 1176/3350
# Processed batch 1177/3350
# Processed batch 1178/3350
# Processed batch 1179/3350
# Processed batch 1180/3350
# Processed batch 1181/3350
# Processed batch 1182/3350
# Processed batch 1183/3350
# Processed batch 1184/3350
# Processed batch 1185/3350
# Processed batch 1186/3350
# Processed batch 1187/3350
# Processed batch 1188/3350
# Processed batch 1189/3350
# Processed batch 1190/3350
# Processed batch 1191/3350
# Processed batch 1192/3350
# Processed batch 1193/3350
# Processed batch 1194/3350
# Processed batch 1195/3350
# Processed batch 1196/3350
# Processed batch 1197/3350
# Processed batch 1198/3350
# Processed batch 1199/3350
# Processed batch 1200/3350
# Processed batch 1201/3350
# Processed batch 1202/3350
# Processed batch 1203/3350
# Processed batch 1204/3350
# Processed batch 1205/3350
# Processed batch 1206/3350
# Processed batch 1207/3350
# Processed batch 1208/3350
# Processed batch 1209/3350
# Processed batch 1210/3350
# Processed batch 1211/3350
# Processed batch 1212/3350
# Processed batch 1213/3350
# Processed batch 1214/3350
# Processed batch 1215/3350
# Processed batch 1216/3350
# Processed batch 1217/3350
# Processed batch 1218/3350
# Processed batch 1219/3350
# Processed batch 1220/3350
# Processed batch 1221/3350
# Processed batch 1222/3350
# Processed batch 1223/3350
# Processed batch 1224/3350
# Processed batch 1225/3350
# Processed batch 1226/3350
# Processed batch 1227/3350
# Processed batch 1228/3350
# Processed batch 1229/3350
# Processed batch 1230/3350
# Processed batch 1231/3350
# Processed batch 1232/3350
# Processed batch 1233/3350
# Processed batch 1234/3350
# Processed batch 1235/3350
# Processed batch 1236/3350
# Processed batch 1237/3350
# Processed batch 1238/3350
# Processed batch 1239/3350
# Processed batch 1240/3350
# Processed batch 1241/3350
# Processed batch 1242/3350
# Processed batch 1243/3350
# Processed batch 1244/3350
# Processed batch 1245/3350
# Processed batch 1246/3350
# Processed batch 1247/3350
# Processed batch 1248/3350
# Processed batch 1249/3350
# Processed batch 1250/3350
# Processed batch 1251/3350
# Processed batch 1252/3350
# Processed batch 1253/3350
# Processed batch 1254/3350
# Processed batch 1255/3350
# Processed batch 1256/3350
# Processed batch 1257/3350
# Processed batch 1258/3350
# Processed batch 1259/3350
# Processed batch 1260/3350
# Processed batch 1261/3350
# Processed batch 1262/3350
# Processed batch 1263/3350
# Processed batch 1264/3350
# Processed batch 1265/3350
# Processed batch 1266/3350
# Processed batch 1267/3350
# Processed batch 1268/3350
# Processed batch 1269/3350
# Processed batch 1270/3350
# Processed batch 1271/3350
# Processed batch 1272/3350
# Processed batch 1273/3350
# Processed batch 1274/3350
# Processed batch 1275/3350
# Processed batch 1276/3350
# Processed batch 1277/3350
# Processed batch 1278/3350
# Processed batch 1279/3350
# Processed batch 1280/3350
# Processed batch 1281/3350
# Processed batch 1282/3350
# Processed batch 1283/3350
# Processed batch 1284/3350
# Processed batch 1285/3350
# Processed batch 1286/3350
# Processed batch 1287/3350
# Processed batch 1288/3350
# Processed batch 1289/3350
# Processed batch 1290/3350
# Processed batch 1291/3350
# Processed batch 1292/3350
# Processed batch 1293/3350
# Processed batch 1294/3350
# Processed batch 1295/3350
# Processed batch 1296/3350
# Processed batch 1297/3350
# Processed batch 1298/3350
# Processed batch 1299/3350
# Processed batch 1300/3350
# Processed batch 1301/3350
# Processed batch 1302/3350
# Processed batch 1303/3350
# Processed batch 1304/3350
# Processed batch 1305/3350
# Processed batch 1306/3350
# Processed batch 1307/3350
# Processed batch 1308/3350
# Processed batch 1309/3350
# Processed batch 1310/3350
# Processed batch 1311/3350
# Processed batch 1312/3350
# Processed batch 1313/3350
# Processed batch 1314/3350
# Processed batch 1315/3350
# Processed batch 1316/3350
# Processed batch 1317/3350
# Processed batch 1318/3350
# Processed batch 1319/3350
# Processed batch 1320/3350
# Processed batch 1321/3350
# Processed batch 1322/3350
# Processed batch 1323/3350
# Processed batch 1324/3350
# Processed batch 1325/3350
# Processed batch 1326/3350
# Processed batch 1327/3350
# Processed batch 1328/3350
# Processed batch 1329/3350
# Processed batch 1330/3350
# Processed batch 1331/3350
# Processed batch 1332/3350
# Processed batch 1333/3350
# Processed batch 1334/3350
# Processed batch 1335/3350
# Processed batch 1336/3350
# Processed batch 1337/3350
# Processed batch 1338/3350
# Processed batch 1339/3350
# Processed batch 1340/3350
# Processed batch 1341/3350
# Processed batch 1342/3350
# Processed batch 1343/3350
# Processed batch 1344/3350
# Processed batch 1345/3350
# Processed batch 1346/3350
# Processed batch 1347/3350
# Processed batch 1348/3350
# Processed batch 1349/3350
# Processed batch 1350/3350
# Processed batch 1351/3350
# Processed batch 1352/3350
# Processed batch 1353/3350
# Processed batch 1354/3350
# Processed batch 1355/3350
# Processed batch 1356/3350
# Processed batch 1357/3350
# Processed batch 1358/3350
# Processed batch 1359/3350
# Processed batch 1360/3350
# Processed batch 1361/3350
# Processed batch 1362/3350
# Processed batch 1363/3350
# Processed batch 1364/3350
# Processed batch 1365/3350
# Processed batch 1366/3350
# Processed batch 1367/3350
# Processed batch 1368/3350
# Processed batch 1369/3350
# Processed batch 1370/3350
# Processed batch 1371/3350
# Processed batch 1372/3350
# Processed batch 1373/3350
# Processed batch 1374/3350
# Processed batch 1375/3350
# Processed batch 1376/3350
# Processed batch 1377/3350
# Processed batch 1378/3350
# Processed batch 1379/3350
# Processed batch 1380/3350
# Processed batch 1381/3350
# Processed batch 1382/3350
# Processed batch 1383/3350
# Processed batch 1384/3350
# Processed batch 1385/3350
# Processed batch 1386/3350
# Processed batch 1387/3350
# Processed batch 1388/3350
# Processed batch 1389/3350
# Processed batch 1390/3350
# Processed batch 1391/3350
# Processed batch 1392/3350
# Processed batch 1393/3350
# Processed batch 1394/3350
# Processed batch 1395/3350
# Processed batch 1396/3350
# Processed batch 1397/3350
# Processed batch 1398/3350
# Processed batch 1399/3350
# Processed batch 1400/3350
# Processed batch 1401/3350
# Processed batch 1402/3350
# Processed batch 1403/3350
# Processed batch 1404/3350
# Processed batch 1405/3350
# Processed batch 1406/3350
# Processed batch 1407/3350
# Processed batch 1408/3350
# Processed batch 1409/3350
# Processed batch 1410/3350
# Processed batch 1411/3350
# Processed batch 1412/3350
# Processed batch 1413/3350
# Processed batch 1414/3350
# Processed batch 1415/3350
# Processed batch 1416/3350
# Processed batch 1417/3350
# Processed batch 1418/3350
# Processed batch 1419/3350
# Processed batch 1420/3350
# Processed batch 1421/3350
# Processed batch 1422/3350
# Processed batch 1423/3350
# Processed batch 1424/3350
# Processed batch 1425/3350
# Processed batch 1426/3350
# Processed batch 1427/3350
# Processed batch 1428/3350
# Processed batch 1429/3350
# Processed batch 1430/3350
# Processed batch 1431/3350
# Processed batch 1432/3350
# Processed batch 1433/3350
# Processed batch 1434/3350
# Processed batch 1435/3350
# Processed batch 1436/3350
# Processed batch 1437/3350
# Processed batch 1438/3350
# Processed batch 1439/3350
# Processed batch 1440/3350
# Processed batch 1441/3350
# Processed batch 1442/3350
# Processed batch 1443/3350
# Processed batch 1444/3350
# Processed batch 1445/3350
# Processed batch 1446/3350
# Processed batch 1447/3350
# Processed batch 1448/3350
# Processed batch 1449/3350
# Processed batch 1450/3350
# Processed batch 1451/3350
# Processed batch 1452/3350
# Processed batch 1453/3350
# Processed batch 1454/3350
# Processed batch 1455/3350
# Processed batch 1456/3350
# Processed batch 1457/3350
# Processed batch 1458/3350
# Processed batch 1459/3350
# Processed batch 1460/3350
# Processed batch 1461/3350
# Processed batch 1462/3350
# Processed batch 1463/3350
# Processed batch 1464/3350
# Processed batch 1465/3350
# Processed batch 1466/3350
# Processed batch 1467/3350
# Processed batch 1468/3350
# Processed batch 1469/3350
# Processed batch 1470/3350
# Processed batch 1471/3350
# Processed batch 1472/3350
# Processed batch 1473/3350
# Processed batch 1474/3350
# Processed batch 1475/3350
# Processed batch 1476/3350
# Processed batch 1477/3350
# Processed batch 1478/3350
# Processed batch 1479/3350
# Processed batch 1480/3350
# Processed batch 1481/3350
# Processed batch 1482/3350
# Processed batch 1483/3350
# Processed batch 1484/3350
# Processed batch 1485/3350
# Processed batch 1486/3350
# Processed batch 1487/3350
# Processed batch 1488/3350
# Processed batch 1489/3350
# Processed batch 1490/3350
# Processed batch 1491/3350
# Processed batch 1492/3350
# Processed batch 1493/3350
# Processed batch 1494/3350
# Processed batch 1495/3350
# Processed batch 1496/3350
# Processed batch 1497/3350
# Processed batch 1498/3350
# Processed batch 1499/3350
# Processed batch 1500/3350
# Processed batch 1501/3350
# Processed batch 1502/3350
# Processed batch 1503/3350
# Processed batch 1504/3350
# Processed batch 1505/3350
# Processed batch 1506/3350
# Processed batch 1507/3350
# Processed batch 1508/3350
# Processed batch 1509/3350
# Processed batch 1510/3350
# Processed batch 1511/3350
# Processed batch 1512/3350
# Processed batch 1513/3350
# Processed batch 1514/3350
# Processed batch 1515/3350
# Processed batch 1516/3350
# Processed batch 1517/3350
# Processed batch 1518/3350
# Processed batch 1519/3350
# Processed batch 1520/3350
# Processed batch 1521/3350
# Processed batch 1522/3350
# Processed batch 1523/3350
# Processed batch 1524/3350
# Processed batch 1525/3350
# Processed batch 1526/3350
# Processed batch 1527/3350
# Processed batch 1528/3350
# Processed batch 1529/3350
# Processed batch 1530/3350
# Processed batch 1531/3350
# Processed batch 1532/3350
# Processed batch 1533/3350
# Processed batch 1534/3350
# Processed batch 1535/3350
# Processed batch 1536/3350
# Processed batch 1537/3350
# Processed batch 1538/3350
# Processed batch 1539/3350
# Processed batch 1540/3350
# Processed batch 1541/3350
# Processed batch 1542/3350
# Processed batch 1543/3350
# Processed batch 1544/3350
# Processed batch 1545/3350
# Processed batch 1546/3350
# Processed batch 1547/3350
# Processed batch 1548/3350
# Processed batch 1549/3350
# Processed batch 1550/3350
# Processed batch 1551/3350
# Processed batch 1552/3350
# Processed batch 1553/3350
# Processed batch 1554/3350
# Processed batch 1555/3350
# Processed batch 1556/3350
# Processed batch 1557/3350
# Processed batch 1558/3350
# Processed batch 1559/3350
# Processed batch 1560/3350
# Processed batch 1561/3350
# Processed batch 1562/3350
# Processed batch 1563/3350
# Processed batch 1564/3350
# Processed batch 1565/3350
# Processed batch 1566/3350
# Processed batch 1567/3350
# Processed batch 1568/3350
# Processed batch 1569/3350
# Processed batch 1570/3350
# Processed batch 1571/3350
# Processed batch 1572/3350
# Processed batch 1573/3350
# Processed batch 1574/3350
# Processed batch 1575/3350
# Processed batch 1576/3350
# Processed batch 1577/3350
# Processed batch 1578/3350
# Processed batch 1579/3350
# Processed batch 1580/3350
# Processed batch 1581/3350
# Processed batch 1582/3350
# Processed batch 1583/3350
# Processed batch 1584/3350
# Processed batch 1585/3350
# Processed batch 1586/3350
# Processed batch 1587/3350
# Processed batch 1588/3350
# Processed batch 1589/3350
# Processed batch 1590/3350
# Processed batch 1591/3350
# Processed batch 1592/3350
# Processed batch 1593/3350
# Processed batch 1594/3350
# Processed batch 1595/3350
# Processed batch 1596/3350
# Processed batch 1597/3350
# Processed batch 1598/3350
# Processed batch 1599/3350
# Processed batch 1600/3350
# Processed batch 1601/3350
# Processed batch 1602/3350
# Processed batch 1603/3350
# Processed batch 1604/3350
# Processed batch 1605/3350
# Processed batch 1606/3350
# Processed batch 1607/3350
# Processed batch 1608/3350
# Processed batch 1609/3350
# Processed batch 1610/3350
# Processed batch 1611/3350
# Processed batch 1612/3350
# Processed batch 1613/3350
# Processed batch 1614/3350
# Processed batch 1615/3350
# Processed batch 1616/3350
# Processed batch 1617/3350
# Processed batch 1618/3350
# Processed batch 1619/3350
# Processed batch 1620/3350
# Processed batch 1621/3350
# Processed batch 1622/3350
# Processed batch 1623/3350
# Processed batch 1624/3350
# Processed batch 1625/3350
# Processed batch 1626/3350
# Processed batch 1627/3350
# Processed batch 1628/3350
# Processed batch 1629/3350
# Processed batch 1630/3350
# Processed batch 1631/3350
# Processed batch 1632/3350
# Processed batch 1633/3350
# Processed batch 1634/3350
# Processed batch 1635/3350
# Processed batch 1636/3350
# Processed batch 1637/3350
# Processed batch 1638/3350
# Processed batch 1639/3350
# Processed batch 1640/3350
# Processed batch 1641/3350
# Processed batch 1642/3350
# Processed batch 1643/3350
# Processed batch 1644/3350
# Processed batch 1645/3350
# Processed batch 1646/3350
# Processed batch 1647/3350
# Processed batch 1648/3350
# Processed batch 1649/3350
# Processed batch 1650/3350
# Processed batch 1651/3350
# Processed batch 1652/3350
# Processed batch 1653/3350
# Processed batch 1654/3350
# Processed batch 1655/3350
# Processed batch 1656/3350
# Processed batch 1657/3350
# Processed batch 1658/3350
# Processed batch 1659/3350
# Processed batch 1660/3350
# Processed batch 1661/3350
# Processed batch 1662/3350
# Processed batch 1663/3350
# Processed batch 1664/3350
# Processed batch 1665/3350
# Processed batch 1666/3350
# Processed batch 1667/3350
# Processed batch 1668/3350
# Processed batch 1669/3350
# Processed batch 1670/3350
# Processed batch 1671/3350
# Processed batch 1672/3350
# Processed batch 1673/3350
# Processed batch 1674/3350
# Processed batch 1675/3350
# Processed batch 1676/3350
# Processed batch 1677/3350
# Processed batch 1678/3350
# Processed batch 1679/3350
# Processed batch 1680/3350
# Processed batch 1681/3350
# Processed batch 1682/3350
# Processed batch 1683/3350
# Processed batch 1684/3350
# Processed batch 1685/3350
# Processed batch 1686/3350
# Processed batch 1687/3350
# Processed batch 1688/3350
# Processed batch 1689/3350
# Processed batch 1690/3350
# Processed batch 1691/3350
# Processed batch 1692/3350
# Processed batch 1693/3350
# Processed batch 1694/3350
# Processed batch 1695/3350
# Processed batch 1696/3350
# Processed batch 1697/3350
# Processed batch 1698/3350
# Processed batch 1699/3350
# Processed batch 1700/3350
# Processed batch 1701/3350
# Processed batch 1702/3350
# Processed batch 1703/3350
# Processed batch 1704/3350
# Processed batch 1705/3350
# Processed batch 1706/3350
# Processed batch 1707/3350
# Processed batch 1708/3350
# Processed batch 1709/3350
# Processed batch 1710/3350
# Processed batch 1711/3350
# Processed batch 1712/3350
# Processed batch 1713/3350
# Processed batch 1714/3350
# Processed batch 1715/3350
# Processed batch 1716/3350
# Processed batch 1717/3350
# Processed batch 1718/3350
# Processed batch 1719/3350
# Processed batch 1720/3350
# Processed batch 1721/3350
# Processed batch 1722/3350
# Processed batch 1723/3350
# Processed batch 1724/3350
# Processed batch 1725/3350
# Processed batch 1726/3350
# Processed batch 1727/3350
# Processed batch 1728/3350
# Processed batch 1729/3350
# Processed batch 1730/3350
# Processed batch 1731/3350
# Processed batch 1732/3350
# Processed batch 1733/3350
# Processed batch 1734/3350
# Processed batch 1735/3350
# Processed batch 1736/3350
# Processed batch 1737/3350
# Processed batch 1738/3350
# Processed batch 1739/3350
# Processed batch 1740/3350
# Processed batch 1741/3350
# Processed batch 1742/3350
# Processed batch 1743/3350
# Processed batch 1744/3350
# Processed batch 1745/3350
# Processed batch 1746/3350
# Processed batch 1747/3350
# Processed batch 1748/3350
# Processed batch 1749/3350
# Processed batch 1750/3350
# Processed batch 1751/3350
# Processed batch 1752/3350
# Processed batch 1753/3350
# Processed batch 1754/3350
# Processed batch 1755/3350
# Processed batch 1756/3350
# Processed batch 1757/3350
# Processed batch 1758/3350
# Processed batch 1759/3350
# Processed batch 1760/3350
# Processed batch 1761/3350
# Processed batch 1762/3350
# Processed batch 1763/3350
# Processed batch 1764/3350
# Processed batch 1765/3350
# Processed batch 1766/3350
# Processed batch 1767/3350
# Processed batch 1768/3350
# Processed batch 1769/3350
# Processed batch 1770/3350
# Processed batch 1771/3350
# Processed batch 1772/3350
# Processed batch 1773/3350
# Processed batch 1774/3350
# Processed batch 1775/3350
# Processed batch 1776/3350
# Processed batch 1777/3350
# Processed batch 1778/3350
# Processed batch 1779/3350
# Processed batch 1780/3350
# Processed batch 1781/3350
# Processed batch 1782/3350
# Processed batch 1783/3350
# Processed batch 1784/3350
# Processed batch 1785/3350
# Processed batch 1786/3350
# Processed batch 1787/3350
# Processed batch 1788/3350
# Processed batch 1789/3350
# Processed batch 1790/3350
# Processed batch 1791/3350
# Processed batch 1792/3350
# Processed batch 1793/3350
# Processed batch 1794/3350
# Processed batch 1795/3350
# Processed batch 1796/3350
# Processed batch 1797/3350
# Processed batch 1798/3350
# Processed batch 1799/3350
# Processed batch 1800/3350
# Processed batch 1801/3350
# Processed batch 1802/3350
# Processed batch 1803/3350
# Processed batch 1804/3350
# Processed batch 1805/3350
# Processed batch 1806/3350
# Processed batch 1807/3350
# Processed batch 1808/3350
# Processed batch 1809/3350
# Processed batch 1810/3350
# Processed batch 1811/3350
# Processed batch 1812/3350
# Processed batch 1813/3350
# Processed batch 1814/3350
# Processed batch 1815/3350
# Processed batch 1816/3350
# Processed batch 1817/3350
# Processed batch 1818/3350
# Processed batch 1819/3350
# Processed batch 1820/3350
# Processed batch 1821/3350
# Processed batch 1822/3350
# Processed batch 1823/3350
# Processed batch 1824/3350
# Processed batch 1825/3350
# Processed batch 1826/3350
# Processed batch 1827/3350
# Processed batch 1828/3350
# Processed batch 1829/3350
# Processed batch 1830/3350
# Processed batch 1831/3350
# Processed batch 1832/3350
# Processed batch 1833/3350
# Processed batch 1834/3350
# Processed batch 1835/3350
# Processed batch 1836/3350
# Processed batch 1837/3350
# Processed batch 1838/3350
# Processed batch 1839/3350
# Processed batch 1840/3350
# Processed batch 1841/3350
# Processed batch 1842/3350
# Processed batch 1843/3350
# Processed batch 1844/3350
# Processed batch 1845/3350
# Processed batch 1846/3350
# Processed batch 1847/3350
# Processed batch 1848/3350
# Processed batch 1849/3350
# Processed batch 1850/3350
# Processed batch 1851/3350
# Processed batch 1852/3350
# Processed batch 1853/3350
# Processed batch 1854/3350
# Processed batch 1855/3350
# Processed batch 1856/3350
# Processed batch 1857/3350
# Processed batch 1858/3350
# Processed batch 1859/3350
# Processed batch 1860/3350
# Processed batch 1861/3350
# Processed batch 1862/3350
# Processed batch 1863/3350
# Processed batch 1864/3350
# Processed batch 1865/3350
# Processed batch 1866/3350
# Processed batch 1867/3350
# Processed batch 1868/3350
# Processed batch 1869/3350
# Processed batch 1870/3350
# Processed batch 1871/3350
# Processed batch 1872/3350
# Processed batch 1873/3350
# Processed batch 1874/3350
# Processed batch 1875/3350
# Processed batch 1876/3350
# Processed batch 1877/3350
# Processed batch 1878/3350
# Processed batch 1879/3350
# Processed batch 1880/3350
# Processed batch 1881/3350
# Processed batch 1882/3350
# Processed batch 1883/3350
# Processed batch 1884/3350
# Processed batch 1885/3350
# Processed batch 1886/3350
# Processed batch 1887/3350
# Processed batch 1888/3350
# ...
# Processed batch 2736/3350
# Processed batch 2737/3350
# Processed batch 2738/3350
# Processed batch 2739/3350
# Processed batch 2740/3350
# Processed batch 2741/3350
# Processed batch 2742/3350
# Processed batch 2743/3350
# Processed batch 2744/3350
# Processed batch 2745/3350
# Processed batch 2746/3350
# Processed batch 2747/3350
# Processed batch 2748/3350
# Processed batch 2749/3350
# Processed batch 2750/3350
# Processed batch 2751/3350
# Processed batch 2752/3350
# Processed batch 2753/3350
# Processed batch 2754/3350
# Processed batch 2755/3350
# Processed batch 2756/3350
# Processed batch 2757/3350
# Processed batch 2758/3350
# Processed batch 2759/3350
# Processed batch 2760/3350
# Processed batch 2761/3350
# Processed batch 2762/3350
# Processed batch 2763/3350
# Processed batch 2764/3350
# Processed batch 2765/3350
# Processed batch 2766/3350
# Processed batch 2767/3350
# Processed batch 2768/3350
# Processed batch 2769/3350
# Processed batch 2770/3350
# Processed batch 2771/3350
# Processed batch 2772/3350
# Processed batch 2773/3350
# Processed batch 2774/3350
# Processed batch 2775/3350
# Processed batch 2776/3350
# Processed batch 2777/3350
# Processed batch 2778/3350
# Processed batch 2779/3350
# Processed batch 2780/3350
# Processed batch 2781/3350
# Processed batch 2782/3350
# Processed batch 2783/3350
# Processed batch 2784/3350
# Processed batch 2785/3350
# Processed batch 2786/3350
# Processed batch 2787/3350
# Processed batch 2788/3350
# Processed batch 2789/3350
# Processed batch 2790/3350
# Processed batch 2791/3350
# Processed batch 2792/3350
# Processed batch 2793/3350
# Processed batch 2794/3350
# Processed batch 2795/3350
# Processed batch 2796/3350
# Processed batch 2797/3350
# Processed batch 2798/3350
# Processed batch 2799/3350
# Processed batch 2800/3350
# Processed batch 2801/3350
# Processed batch 2802/3350
# Processed batch 2803/3350
# Processed batch 2804/3350
# Processed batch 2805/3350
# Processed batch 2806/3350
# Processed batch 2807/3350
# Processed batch 2808/3350
# Processed batch 2809/3350
# Processed batch 2810/3350
# Processed batch 2811/3350
# Processed batch 2812/3350
# Processed batch 2813/3350
# Processed batch 2814/3350
# Processed batch 2815/3350
# Processed batch 2816/3350
# Processed batch 2817/3350
# Processed batch 2818/3350
# Processed batch 2819/3350
# Processed batch 2820/3350
# Processed batch 2821/3350
# Processed batch 2822/3350
# Processed batch 2823/3350
# Processed batch 2824/3350
# Processed batch 2825/3350
# Processed batch 2826/3350
# Processed batch 2827/3350
# Processed batch 2828/3350
# Processed batch 2829/3350
# Processed batch 2830/3350
# Processed batch 2831/3350
# Processed batch 2832/3350
# Processed batch 2833/3350
# Processed batch 2834/3350
# Processed batch 2835/3350
# Processed batch 2836/3350
# Processed batch 2837/3350
# Processed batch 2838/3350
# Processed batch 2839/3350
# Processed batch 2840/3350
# Processed batch 2841/3350
# Processed batch 2842/3350
# Processed batch 2843/3350
# Processed batch 2844/3350
# Processed batch 2845/3350
# Processed batch 2846/3350
# Processed batch 2847/3350
# Processed batch 2848/3350
# Processed batch 2849/3350
# Processed batch 2850/3350
# Processed batch 2851/3350
# Processed batch 2852/3350
# Processed batch 2853/3350
# Processed batch 2854/3350
# Processed batch 2855/3350
# Processed batch 2856/3350
# Processed batch 2857/3350
# Processed batch 2858/3350
# Processed batch 2859/3350
# Processed batch 2860/3350
# Processed batch 2861/3350
# Processed batch 2862/3350
# Processed batch 2863/3350
# Processed batch 2864/3350
# Processed batch 2865/3350
# Processed batch 2866/3350
# Processed batch 2867/3350
# Processed batch 2868/3350
# Processed batch 2869/3350
# Processed batch 2870/3350
# Processed batch 2871/3350
# Processed batch 2872/3350
# Processed batch 2873/3350
# Processed batch 2874/3350
# Processed batch 2875/3350
# Processed batch 2876/3350
# Processed batch 2877/3350
# Processed batch 2878/3350
# Processed batch 2879/3350
# Processed batch 2880/3350
# Processed batch 2881/3350
# Processed batch 2882/3350
# Processed batch 2883/3350
# Processed batch 2884/3350
# Processed batch 2885/3350
# Processed batch 2886/3350
# Processed batch 2887/3350
# Processed batch 2888/3350
# Processed batch 2889/3350
# Processed batch 2890/3350
# Processed batch 2891/3350
# Processed batch 2892/3350
# Processed batch 2893/3350
# Processed batch 2894/3350
# Processed batch 2895/3350
# Processed batch 2896/3350
# Processed batch 2897/3350
# Processed batch 2898/3350
# Processed batch 2899/3350
# Processed batch 2900/3350
# Processed batch 2901/3350
# Processed batch 2902/3350
# Processed batch 2903/3350
# Processed batch 2904/3350
# Processed batch 2905/3350
# Processed batch 2906/3350
# Processed batch 2907/3350
# Processed batch 2908/3350
# Processed batch 2909/3350
# Processed batch 2910/3350
# Processed batch 2911/3350
# Processed batch 2912/3350
# Processed batch 2913/3350
# Processed batch 2914/3350
# Processed batch 2915/3350
# Processed batch 2916/3350
# Processed batch 2917/3350
# Processed batch 2918/3350
# Processed batch 2919/3350
# Processed batch 2920/3350
# Processed batch 2921/3350
# Processed batch 2922/3350
# Processed batch 2923/3350
# Processed batch 2924/3350
# Processed batch 2925/3350
# Processed batch 2926/3350
# Processed batch 2927/3350
# Processed batch 2928/3350
# Processed batch 2929/3350
# Processed batch 2930/3350
# Processed batch 2931/3350
# Processed batch 2932/3350
# Processed batch 2933/3350
# Processed batch 2934/3350
# Processed batch 2935/3350
# Processed batch 2936/3350
# Processed batch 2937/3350
# Processed batch 2938/3350
# Processed batch 2939/3350
# Processed batch 2940/3350
# Processed batch 2941/3350
# Processed batch 2942/3350
# Processed batch 2943/3350
# Processed batch 2944/3350
# Processed batch 2945/3350
# Processed batch 2946/3350
# Processed batch 2947/3350
# Processed batch 2948/3350
# Processed batch 2949/3350
# Processed batch 2950/3350
# Processed batch 2951/3350
# Processed batch 2952/3350
# Processed batch 2953/3350
# Processed batch 2954/3350
# Processed batch 2955/3350
# Processed batch 2956/3350
# Processed batch 2957/3350
# Processed batch 2958/3350
# Processed batch 2959/3350
# Processed batch 2960/3350
# Processed batch 2961/3350
# Processed batch 2962/3350
# Processed batch 2963/3350
# Processed batch 2964/3350
# Processed batch 2965/3350
# Processed batch 2966/3350
# Processed batch 2967/3350
# Processed batch 2968/3350
# Processed batch 2969/3350
# Processed batch 2970/3350
# Processed batch 2971/3350
# Processed batch 2972/3350
# Processed batch 2973/3350
# Processed batch 2974/3350
# Processed batch 2975/3350
# Processed batch 2976/3350
# Processed batch 2977/3350
# Processed batch 2978/3350
# Processed batch 2979/3350
# Processed batch 2980/3350
# Processed batch 2981/3350
# Processed batch 2982/3350
# Processed batch 2983/3350
# Processed batch 2984/3350
# Processed batch 2985/3350
# Processed batch 2986/3350
# Processed batch 2987/3350
# Processed batch 2988/3350
# Processed batch 2989/3350
# Processed batch 2990/3350
# Processed batch 2991/3350
# Processed batch 2992/3350
# Processed batch 2993/3350
# Processed batch 2994/3350
# Processed batch 2995/3350
# Processed batch 2996/3350
# Processed batch 2997/3350
# Processed batch 2998/3350
# Processed batch 2999/3350
# Processed batch 3000/3350
# Processed batch 3001/3350
# Processed batch 3002/3350
# Processed batch 3003/3350
# Processed batch 3004/3350
# Processed batch 3005/3350
# Processed batch 3006/3350
# Processed batch 3007/3350
# Processed batch 3008/3350
# Processed batch 3009/3350
# Processed batch 3010/3350
# Processed batch 3011/3350
# Processed batch 3012/3350
# Processed batch 3013/3350
# Processed batch 3014/3350
# Processed batch 3015/3350
# Processed batch 3016/3350
# Processed batch 3017/3350
# Processed batch 3018/3350
# Processed batch 3019/3350
# Processed batch 3020/3350
# Processed batch 3021/3350
# Processed batch 3022/3350
# Processed batch 3023/3350
# Processed batch 3024/3350
# Processed batch 3025/3350
# Processed batch 3026/3350
# Processed batch 3027/3350
# Processed batch 3028/3350
# Processed batch 3029/3350
# Processed batch 3030/3350
# Processed batch 3031/3350
# Processed batch 3032/3350
# Processed batch 3033/3350
# Processed batch 3034/3350
# Processed batch 3035/3350
# Processed batch 3036/3350
# Processed batch 3037/3350
# Processed batch 3038/3350
# Processed batch 3039/3350
# Processed batch 3040/3350
# Processed batch 3041/3350
# Processed batch 3042/3350
# Processed batch 3043/3350
# Processed batch 3044/3350
# Processed batch 3045/3350
# Processed batch 3046/3350
# Processed batch 3047/3350
# Processed batch 3048/3350
# Processed batch 3049/3350
# Processed batch 3050/3350
# Processed batch 3051/3350
# Processed batch 3052/3350
# Processed batch 3053/3350
# Processed batch 3054/3350
# Processed batch 3055/3350
# Processed batch 3056/3350
# Processed batch 3057/3350
# Processed batch 3058/3350
# Processed batch 3059/3350
# Processed batch 3060/3350
# Processed batch 3061/3350
# Processed batch 3062/3350
# Processed batch 3063/3350
# Processed batch 3064/3350
# Processed batch 3065/3350
# Processed batch 3066/3350
# Processed batch 3067/3350
# Processed batch 3068/3350
# Processed batch 3069/3350
# Processed batch 3070/3350
# Processed batch 3071/3350
# Processed batch 3072/3350
# Processed batch 3073/3350
# Processed batch 3074/3350
# Processed batch 3075/3350
# Processed batch 3076/3350
# Processed batch 3077/3350
# Processed batch 3078/3350
# Processed batch 3079/3350
# Processed batch 3080/3350
# Processed batch 3081/3350
# Processed batch 3082/3350
# Processed batch 3083/3350
# Processed batch 3084/3350
# Processed batch 3085/3350
# Processed batch 3086/3350
# Processed batch 3087/3350
# Processed batch 3088/3350
# Processed batch 3089/3350
# Processed batch 3090/3350
# Processed batch 3091/3350
# Processed batch 3092/3350
# Processed batch 3093/3350
# Processed batch 3094/3350
# Processed batch 3095/3350
# Processed batch 3096/3350
# Processed batch 3097/3350
# Processed batch 3098/3350
# Processed batch 3099/3350
# Processed batch 3100/3350
# Processed batch 3101/3350
# Processed batch 3102/3350
# Processed batch 3103/3350
# Processed batch 3104/3350
# Processed batch 3105/3350
# Processed batch 3106/3350
# Processed batch 3107/3350
# Processed batch 3108/3350
# Processed batch 3109/3350
# Processed batch 3110/3350
# Processed batch 3111/3350
# Processed batch 3112/3350
# Processed batch 3113/3350
# Processed batch 3114/3350
# Processed batch 3115/3350
# Processed batch 3116/3350
# Processed batch 3117/3350
# Processed batch 3118/3350
# Processed batch 3119/3350
# Processed batch 3120/3350
# Processed batch 3121/3350
# Processed batch 3122/3350
# Processed batch 3123/3350
# Processed batch 3124/3350
# Processed batch 3125/3350
# Processed batch 3126/3350
# Processed batch 3127/3350
# Processed batch 3128/3350
# Processed batch 3129/3350
# Processed batch 3130/3350
# Processed batch 3131/3350
# Processed batch 3132/3350
# Processed batch 3133/3350
# Processed batch 3134/3350
# Processed batch 3135/3350
# Processed batch 3136/3350
# Processed batch 3137/3350
# Processed batch 3138/3350
# Processed batch 3139/3350
# Processed batch 3140/3350
# Processed batch 3141/3350
# Processed batch 3142/3350
# Processed batch 3143/3350
# Processed batch 3144/3350
# Processed batch 3145/3350
# Processed batch 3146/3350
# Processed batch 3147/3350
# Processed batch 3148/3350
# Processed batch 3149/3350
# Processed batch 3150/3350
# Processed batch 3151/3350
# Processed batch 3152/3350
# Processed batch 3153/3350
# Processed batch 3154/3350
# Processed batch 3155/3350
# Processed batch 3156/3350
# Processed batch 3157/3350
# Processed batch 3158/3350
# Processed batch 3159/3350
# Processed batch 3160/3350
# Processed batch 3161/3350
# Processed batch 3162/3350
# Processed batch 3163/3350
# Processed batch 3164/3350
# Processed batch 3165/3350
# Processed batch 3166/3350
# Processed batch 3167/3350
# Processed batch 3168/3350
# Processed batch 3169/3350
# Processed batch 3170/3350
# Processed batch 3171/3350
# Processed batch 3172/3350
# Processed batch 3173/3350
# Processed batch 3174/3350
# Processed batch 3175/3350
# Processed batch 3176/3350
# Processed batch 3177/3350
# Processed batch 3178/3350
# Processed batch 3179/3350
# Processed batch 3180/3350
# Processed batch 3181/3350
# Processed batch 3182/3350
# Processed batch 3183/3350
# Processed batch 3184/3350
# Processed batch 3185/3350
# Processed batch 3186/3350
# Processed batch 3187/3350
# Processed batch 3188/3350
# Processed batch 3189/3350
# Processed batch 3190/3350
# Processed batch 3191/3350
# Processed batch 3192/3350
# Processed batch 3193/3350
# Processed batch 3194/3350
# Processed batch 3195/3350
# Processed batch 3196/3350
# Processed batch 3197/3350
# Processed batch 3198/3350
# Processed batch 3199/3350
# Processed batch 3200/3350
# Processed batch 3201/3350
# Processed batch 3202/3350
# Processed batch 3203/3350
# Processed batch 3204/3350
# Processed batch 3205/3350
# Processed batch 3206/3350
# Processed batch 3207/3350
# Processed batch 3208/3350
# Processed batch 3209/3350
# Processed batch 3210/3350
# Processed batch 3211/3350
# Processed batch 3212/3350
# Processed batch 3213/3350
# Processed batch 3214/3350
# Processed batch 3215/3350
# Processed batch 3216/3350
# Processed batch 3217/3350
# Processed batch 3218/3350
# Processed batch 3219/3350
# Processed batch 3220/3350
# Processed batch 3221/3350
# Processed batch 3222/3350
# Processed batch 3223/3350
# Processed batch 3224/3350
# Processed batch 3225/3350
# Processed batch 3226/3350
# Processed batch 3227/3350
# Processed batch 3228/3350
# Processed batch 3229/3350
# Processed batch 3230/3350
# Processed batch 3231/3350
# Processed batch 3232/3350
# Processed batch 3233/3350
# Processed batch 3234/3350
# Processed batch 3235/3350
# Processed batch 3236/3350
# Processed batch 3237/3350
# Processed batch 3238/3350
# Processed batch 3239/3350
# Processed batch 3240/3350
# Processed batch 3241/3350
# Processed batch 3242/3350
# Processed batch 3243/3350
# Processed batch 3244/3350
# Processed batch 3245/3350
# Processed batch 3246/3350
# Processed batch 3247/3350
# Processed batch 3248/3350
# Processed batch 3249/3350
# Processed batch 3250/3350
# Processed batch 3251/3350
# Processed batch 3252/3350
# Processed batch 3253/3350
# Processed batch 3254/3350
# Processed batch 3255/3350
# Processed batch 3256/3350
# Processed batch 3257/3350
# Processed batch 3258/3350
# Processed batch 3259/3350
# Processed batch 3260/3350
# Processed batch 3261/3350
# Processed batch 3262/3350
# Processed batch 3263/3350
# Processed batch 3264/3350
# Processed batch 3265/3350
# Processed batch 3266/3350
# Processed batch 3267/3350
# Processed batch 3268/3350
# Processed batch 3269/3350
# Processed batch 3270/3350
# Processed batch 3271/3350
# Processed batch 3272/3350
# Processed batch 3273/3350
# Processed batch 3274/3350
# Processed batch 3275/3350
# Processed batch 3276/3350
# Processed batch 3277/3350
# Processed batch 3278/3350
# Processed batch 3279/3350
# Processed batch 3280/3350
# Processed batch 3281/3350
# Processed batch 3282/3350
# Processed batch 3283/3350
# Processed batch 3284/3350
# Processed batch 3285/3350
# Processed batch 3286/3350
# Processed batch 3287/3350
# Processed batch 3288/3350
# Processed batch 3289/3350
# Processed batch 3290/3350
# Processed batch 3291/3350
# Processed batch 3292/3350
# Processed batch 3293/3350
# Processed batch 3294/3350
# Processed batch 3295/3350
# Processed batch 3296/3350
# Processed batch 3297/3350
# Processed batch 3298/3350
# Processed batch 3299/3350
# Processed batch 3300/3350
# Processed batch 3301/3350
# Processed batch 3302/3350
# Processed batch 3303/3350
# Processed batch 3304/3350
# Processed batch 3305/3350
# Processed batch 3306/3350
# Processed batch 3307/3350
# Processed batch 3308/3350
# Processed batch 3309/3350
# Processed batch 3310/3350
# Processed batch 3311/3350
# Processed batch 3312/3350
# Processed batch 3313/3350
# Processed batch 3314/3350
# Processed batch 3315/3350
# Processed batch 3316/3350
# Processed batch 3317/3350
# Processed batch 3318/3350
# Processed batch 3319/3350
# Processed batch 3320/3350
# Processed batch 3321/3350
# Processed batch 3322/3350
# Processed batch 3323/3350
# Processed batch 3324/3350
# Processed batch 3325/3350
# Processed batch 3326/3350
# Processed batch 3327/3350
# Processed batch 3328/3350
# Processed batch 3329/3350
# Processed batch 3330/3350
# Processed batch 3331/3350
# Processed batch 3332/3350
# Processed batch 3333/3350
# Processed batch 3334/3350
# Processed batch 3335/3350
# Processed batch 3336/3350
# Processed batch 3337/3350
# Processed batch 3338/3350
# Processed batch 3339/3350
# Processed batch 3340/3350
# Processed batch 3341/3350
# Processed batch 3342/3350
# Processed batch 3343/3350
# Processed batch 3344/3350
# Processed batch 3345/3350
# Processed batch 3346/3350
# Processed batch 3347/3350
# Processed batch 3348/3350
# Processed batch 3349/3350
# Processed batch 3350/3350

# %%
ecfp_matrix = ecfp_matrix.astype(np.uint8)

# %%
np.save("data/processed_data/ecfp_test.npy", ecfp_matrix)

# %%
ecfp_matrix.shape

# %%
ecfp_matrix

# %%
df['ecfp'] = df['molecule_smiles'].apply(generate_ecfp)
df

# %%
df = df[['ecfp']]

# %%
df.to_parquet("data/ecfp_train.parquet")

# %%
ecfp = df['ecfp'].apply(pd.Series)
ecfp.columns = [f'ecfp{i+1}' for i in range(ecfp.shape[1])]
ecfp

# %%
ecfp.to_parquet("data/ecfp_train.parquet")
